# %%
#W3A1
#Nhập vào một số nguyên dương có 3 chữ số.
#Tìm và in ra màn hình “SỐ NGUYÊN” đảo ngược của n. Không dùng kiểu chuỗi.
#Chú ý: kiểm tra chỉ xử lý các số nguyên dương có đúng 3 chữ số. Các số khác không xử lý.
a=int(input())
if 100<=a<=999:
    b=a//100
    c=(a-b*100)//10
    d=a-b*100-c*10
    print(f"{d}{c}{b}")
else:
    print("Không xử lý")
# Out:
# 765

# %%
#W3A2 
#Hoán đổi hai số không sd biến tạm thời 
#Sử dụng phép toán XOR trên bit để hoán đổi giá trị của hai biến. 
#Đọc và tự tìm hiểu các phép toán trên bit: AND, OR, XOR
a,b=map(int,(input()).split())
a=a^b
b=a^b
a=a^b
print(f"{a} {b}")
# Out:
# 1 2

# %%
#W3A3 
#Kiểm tra xem một số có phải là lũy thừa của 2 hay không 
#Sử dụng các toán tử bitwise để xác định xem một số có phải là lũy thừa của 2 hay không. 
#Gợi ý: Đối với lũy thừa của 2, n & (n-1) == 0
n=int(input())
if n>0:
    print(n&(n-1)==0)
# Out:
# False

# %%
#W3A4
#viêt chương trình chia một số m cho n, kết quả thu được làm tròn xuống
m,n=map(float,(input().split()))
print(f"{m//n}")
# Out:
# 0.0

# %%
#W3A5
#viêt chương trình chia một số m cho n, kết quả thu được làm tròn lên
m,n=map(int,(input()).split())
print(f"{(m+n-1)//n}")

# %%
#W3A6 [Even and Odd]  
#Nhập vào một số nguyên dương x, bạn hãy kiểm tra xem x là số chẵn hay lẻ. 
#Nếu x là số chẵn, in ra "Even". Nếu x là số lẻ, in ra "Odd".
a=int(input())
if a%2==0:
    print('Even')
else:
    print('Odd')
# Out:
# Odd

# %%
#W3A7 [Check negative numbers] 
#Nhập vào hai số nguyên a, b. Nếu cả hai số a, b đều âm thì in ra "Yes", ngược lại in ra "No". 
a,b=map(int,input().split())
if a<0 and b<0:
    print('Yes')
else:
    print('No')
# Out:
# Yes

# %%
#W3A8 [Longer string] 
#Nhập vào hai chuỗi a, b gồm các chữ cái thường.
#In ra "True" nếu chuỗi a dài hơn chuỗi b. Ngược lại in ra "False". 
a,b=(input().split())
if len(a)>len(b):
    print("True")
else:
    print("False")

# %%
#W3A9 [Triangle]  
#Nhập vào 3 số nguyên dương a, b, c. 
#Kiểm tra xem a, b, c có cấu thành độ dài cạnh của 1 tam giác được không. Nếu a, b, c cấu tạo thành được một tam giác, in ra "Yes". Ngược lại in ra "No". 
a,b,c=map(float,input().split())
if a+b>c and a+c>b and b+c>a:
    print('Yes')
else:
    print('No')
# Out:
# No

# %%
#W3A10 [Largest number] 
#Nhập vào 4 số nguyên. In ra màn hình số nguyên lớn nhất trong 4 số.
a,b,c,d=map(int,input().split())
print(max(a,b,c,d))

# %%
#W3A11 [Phân loại tam giác] 
#Nhập vào 3 số nguyên dương a,b,c là độ dài 3 cạnh của một tam giác.
#Kiểm tra 3 số đã nhập có tạo thành một tam giác hợp lệ hay không.
#Nếu không in ra "Không phải tam giác". 
#Nếu có, phân loại tam giác đó là "Tam giác đều", "Tam giác cân", hay "Tam giác thường".
a,b,c=map(float,input().split())
if a+b>c and a+c>b and b+c>a:
    if a==b!=c or a==c!=b or b==c!=a:
        print('Tam giác cân')
    elif a==b==c:
        print('Tam giác đều')
    else:
        print('Tam giác thường')
else:
    print('Không phải tam giác')
# Out:
# Tam giác đều

# %%
#W3A12 [Kiểm tra năm nhuận] 
#Nhập vào một số nguyên dương n là số năm, kiểm tra xem năm đó có phải là năm nhuận hay không. 
#Năm nhuận là năm chia hết cho 4 nhưng không chia hết cho 100, hoặc chia hết cho 400. 
#Nếu là năm nhuận in ra "Yes", nếu không in ra "No" 
n=int(input())
if n%4==0 and n%100!=0 or a%400==0:
    print('Yes')
else:
    print('No')
# Out:
# No

# %%
#W3A14 [Giải phương trình bậc nhất] 
#Nhập vào hai số thực a và b của phương trình ax + b = 0.
#Tìm và in ra nghiệm của phương trình, kết quả làm tròn đến số thập phân thứ 2. 
#In ra "Vô nghiệm" hoặc "Vô số nghiệm" trong trường hợp tương ứng. 
a,b=map(float,input().split())
if a==0:
    if b==0:
        print("PT vô số nghiệm")
    else:
        print("PT vô nghiệm")
elif a!=0 and b==0:
    print(f"PT có nghiệm duy nhất là x = {0}")
elif a!=0 and b!=0:
    print("PT có nghiệm duy nhất là x= ", round((-b/a),2))
# Out:
# PT có nghiệm duy nhất là x=  -1.33

# %%
#W3A15 [Xếp loại học lực] 
#Nhập vào điểm trung bình của một học sinh và in ra học lực của học sinh đó. 
#Xếp loại học lực theo quy tắc: - >= 8.0: Giỏi - >= 6.5: Khá - >= 5.0: Trung bình - < 5.0: Yếu 
n=float(input())
if n>=8.0:
    print('Giỏi')
elif n>=6.5:
    print('Khá')
elif n>=5.0:
    print('Trung Bình')
else:
    print('Yếu')
# Out:
# Khá

# %%
#W3A16 [Rounding] 
#Nhập vào một số thực: in ra kết quả làm tròn lên, tròn xuống, làm tròn tới số nguyên gần nhất (không được sử dụng hàm sẵn có của pyton).
#Các kết quả cách nhau một dấu cách. 
n=float(input())
a=int(n)
if n>a:
    a+=1
b=int(n)
if n<b:
    b-=1
c=int(n)
if n>c:
    c=int(n+0.5)
elif n<a:
    c=int(n-0.5)
print(a, b, c)
# Out:
# 3 2 2

# %%
#W3A17 Cấp số nhân 
#Cho 4 số a, b, c, d. Hãy kiểm tra xem 4 số này có thể theo thứ tự tạo thành 1 cấp số nhân với công bội nguyên theo đúng thứ tự a, b, c, d hay không? 
#Gợi ý : Tìm công bội (b / a) nếu b chia hết cho a, sau đó lấy b nhân công bội và so sánh vs c, c nhân công bội và so sánh vs d.
a,b,c,d=map(int,input().split())
if b%a==0:
    q=(b/a)
    if b*q==c and c*q==d:
        print('Yes')
    else:
        print('No')
else:
    print('No')
# Out:
# No
